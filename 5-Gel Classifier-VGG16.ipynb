# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Gel_Project_Image_Classification
# Out:
# /content/drive/MyDrive/Gel_Project_Image_Classification

# %% [markdown]
# #1- Training the Model with a Single Linear Layer as the Classifier Head

# %% [markdown]
# #a1- Optimization Algorithm: Adam

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=17 --hardware_type='tpu' --pretrained_model='vgg16' --classifier_head='single' --opt_alg='adam' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/single-layer/Adam/model/gel_classifier-17.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/single-layer/Adam/plots/loss_accuracy_plots/gel_classifier-17.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:08<00:00, 64.6MB/s]
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0338, Train Acc: 60.27%, Val Loss: 0.4904, Val Acc: 89.47%
# Epoch: 2/20, Train Loss: 0.0251, Train Acc: 89.04%, Val Loss: 0.3474, Val Acc: 94.74%
# Epoch: 3/20, Train Loss: 0.0174, Train Acc: 86.30%, Val Loss: 0.2424, Val Acc: 89.47%
# Epoch: 4/20, Train Loss: 0.0127, Train Acc: 90.41%, Val Loss: 0.1628, Val Acc: 94.74%
# Epoch: 5/20, Train Loss: 0.0109, Train Acc: 93.15%, Val Loss: 0.1096, Val Acc: 94.74%
# Epoch: 6/20, Train Loss: 0.0095, Train Acc: 93.15%, Val Loss: 0.1736, Val Acc: 94.74%
# Epoch: 7/20, Train Loss: 0.0074, Train Acc: 94.52%, Val Loss: 0.1773, Val Acc: 94.74%
# Epoch: 8/20, Train Loss: 0.0052, Train Acc: 97.26%, Val Loss: 0.1813, Val Acc: 94.74%
# Epoch: 9/20, Train Loss: 0.0059, Train Acc: 95.89%, Val Loss: 0.1396, Val Acc: 94.74%
# Epoch: 10/20, Train Loss: 0.0038, Train Acc: 97.26%, Val Loss: 0.1193, Val Acc: 94.74%
# Epoch: 11/20, Train Loss: 0.0028, Train Acc: 97.26%, Val Loss: 0.1157, Val Acc: 94.74%
# Epoch: 12/20, Train Loss: 0.0061, Train Acc: 97.26%, Val Loss: 0.0445, Val Acc: 100.00%
# Epoch: 13/20, Train Loss: 0.0028, Train Acc: 98.63%, Val Loss: 0.0654, Val Acc: 100.00%
# Epoch: 14/20, Train Loss: 0.0032, Train Acc: 97.26%, Val Loss: 0.2304, Val Acc: 89.47%
# Epoch: 15/20, Train Loss: 0.0050, Train Acc: 97.26%, Val Loss: 0.1732, Val Acc: 94.74%
# Epoch: 16/20, Train Loss: 0.0037, Train Acc: 98.63%, Val Loss: 0.1915, Val Acc: 94.74%
# Epoch: 17/20, Train Loss: 0.0044, Train Acc: 97.26%, Val Loss: 0.0303, Val Acc: 100.00%
# Epoch: 18/20, Train Loss: 0.0056, Train Acc: 97.26%, Val Loss: 0.0199, Val Acc: 100.00%
# Epoch: 19/20, Train Loss: 0.0018, Train Acc: 100.00%, Val Loss: 0.0406, Val Acc: 100.00%
# Epoch: 20/20, Train Loss: 0.0127, Train Acc: 98.63%, Val Loss: 0.4822, Val Acc: 89.47%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/single-layer/Adam/model/gel_classifier-17.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/single-layer/Adam/plots/loss_accuracy_plots/gel_classifier-17.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# # Import the necessary libraries

# %%
import os
import time
import torch
import pandas as pd
import seaborn as sns
from PIL import Image
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, auc
import utils
import build_dataset
import prepare_model

# %% [markdown]
# #Loading and Preparing Test Dataset

# %%
# Load the test images
test_images = '/content/drive/MyDrive/Gel_Project_Image_Classification/test_images'

# Create a test dataset
test_dataset = build_dataset.GelElectrophoresisDataset(test_images, transform=utils.test_transform)

# Get the number of classes
num_classes = test_dataset.num_classes

# Create dataloader on test images
test_dataloader = DataLoader(test_dataset, batch_size=23, shuffle=False, num_workers=2)

# %% [markdown]
# #Loading The Model

# %%
def load_model(pretrained_model, classifier_head, num_classes, model_path):

    if pretrained_model == 'resnet18':
        model = prepare_model.resnet18(num_classes, classifier_head)
    elif pretrained_model == 'vgg16':
        model = prepare_model.vgg16(num_classes, classifier_head)
    elif pretrained_model == 'mobilenet-v3':
        model = prepare_model.mobilenet_v3(num_classes, classifier_head)
    else:
        raise ValueError("Invalid pretrained model")

    # Load the trained weights of the model from a saved checkpoint file
    model.load_state_dict(torch.load(model_path))

    print("[INFO] Loading the model...")

    # Choose the device to run inference on (GPU if available, else CPU)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    # Move the model to the device
    model = model.to(device)

    # Set the model to evaluation mode
    model.eval()

    print("[INFO] Model loaded!")

    # Return the loaded model and device
    return model, device

# %%
model, device=load_model('vgg16', 'single', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/single-layer/Adam/model/gel_classifier-17.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
def evaluate_metrics(model, device, test_dataloader, model_id):

    # Testing loop
    predictions = []
    targets = []

    # Disables gradient calculation (as gradients are not needed during evaluation)
    with torch.no_grad():
      for inputs, labels in test_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())
        targets.extend(labels.cpu().numpy())

    # Calculate evaluation metrics
    accuracy = accuracy_score(targets, predictions)
    precision = precision_score(targets, predictions, average='weighted')
    recall = recall_score(targets, predictions, average='weighted')
    conf_mat = confusion_matrix(targets, predictions)
    fpr, tpr, thresholds = roc_curve(targets, predictions)
    roc_auc = auc(fpr, tpr)
    print('[INFO] Accuracy: {:.2f}%'.format(accuracy*100))
    print('[INFO] Precision: {:.2f}%'.format(precision*100))
    print('[INFO] Recall: {:.2f}%'.format(recall*100))
    print('[INFO] Confusion matrix:\n', conf_mat)
    print('[INFO] AUC: {:.2f}%'.format(roc_auc*100))

    # Plot confusion matrix
    plt.figure(figsize=(4, 3))
    sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues')
    plt.title('ConfusionMatrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    # Plot ROC curve
    plt.figure(figsize=(4, 3))
    plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = {:.2f}%)'.format(roc_auc*100))
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.show()

    # Store the evaluation metrics in a dictionary
    results = {
        'model_id': model_id,
        'accuracy': '{:.2f}%'.format(accuracy*100),
        'precision': '{:.2f}%'.format(precision*100),
        'recall': '{:.2f}%'.format(recall*100),
        'conf_mat': str(conf_mat.tolist()),
        'roc_auc': '{:.2f}%'.format(roc_auc*100)

    }

    return results

# %%
results = evaluate_metrics(model, device, test_dataloader, 17)
# Out:
# [INFO] Accuracy: 77.27%
# [INFO] Precision: 84.38%
# [INFO] Recall: 77.27%
# [INFO] Confusion matrix:
#  [[ 6  5]
#  [ 0 11]]
# [INFO] AUC: 77.27%

# %%
# Path to results CSV file
results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
def inference(model, device, test_dataloader, test_dataset, model_id):
    # Start inference timer
    inf_start = time.time()

    # Testing loop
    predictions = []
    correct = 0
    total = 0

    # Disables gradient calculation (as gradients are not needed during inference)
    with torch.no_grad():
        for inputs, labels in test_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            predictions.extend(predicted.cpu().numpy())

            # Display images with predicted and actual classes
            for j in range(len(labels)):
                # Get image name and path
                image_path = test_dataset.samples[j][0]
                image_name = os.path.basename(image_path)
                # Load and display image
                img = Image.open(image_path)
                plt.imshow(img, cmap='gray')
                plt.axis('off')
                plt.title(f'Predicted: {test_dataset.image_folder.classes[predictions[j]]}, Actual: {test_dataset.image_folder.classes[labels[j]]}')
                plt.show()

    # End inference timer
    inf_end = time.time()
    # Calculate inference time
    inf_time_secs = inf_end - inf_start
    # Convert seconds to minutes
    inf_time_mins = inf_time_secs / 60
    print("[INFO] Inference completed on test samples")
    # Print total inference time
    print(f"[INFO] Total inference time: {inf_time_secs:.2f} seconds, {inf_time_mins:.2f} minutes")

    # Store inference time in a dictionary
    results = {
      'model_id': model_id,
      'inference_time_secs': inf_time_secs
    }

    return results

# %%
results = inference(model, device, test_dataloader, test_dataset, 17)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #b1- Optimization Algorithm: SGD

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=18 --hardware_type='tpu' --pretrained_model='vgg16' --classifier_head='single' --opt_alg='sgd' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/single-layer/SGD/model/gel_classifier-18.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/single-layer/SGD/plots/loss_accuracy_plots/gel_classifier-18.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:04<00:00, 126MB/s]
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0374, Train Acc: 49.32%, Val Loss: 0.6083, Val Acc: 52.63%
# Epoch: 2/20, Train Loss: 0.0323, Train Acc: 69.86%, Val Loss: 0.4347, Val Acc: 94.74%
# Epoch: 3/20, Train Loss: 0.0243, Train Acc: 89.04%, Val Loss: 0.2671, Val Acc: 100.00%
# Epoch: 4/20, Train Loss: 0.0157, Train Acc: 93.15%, Val Loss: 0.1829, Val Acc: 100.00%
# Epoch: 5/20, Train Loss: 0.0101, Train Acc: 94.52%, Val Loss: 0.2244, Val Acc: 89.47%
# Epoch: 6/20, Train Loss: 0.0105, Train Acc: 91.78%, Val Loss: 0.0985, Val Acc: 100.00%
# Epoch: 7/20, Train Loss: 0.0091, Train Acc: 94.52%, Val Loss: 0.0934, Val Acc: 100.00%
# Epoch: 8/20, Train Loss: 0.0131, Train Acc: 94.52%, Val Loss: 0.0461, Val Acc: 100.00%
# Epoch: 9/20, Train Loss: 0.0149, Train Acc: 93.15%, Val Loss: 0.0602, Val Acc: 100.00%
# Epoch: 10/20, Train Loss: 0.0080, Train Acc: 93.15%, Val Loss: 0.0916, Val Acc: 100.00%
# Epoch: 11/20, Train Loss: 0.0202, Train Acc: 95.89%, Val Loss: 0.0508, Val Acc: 100.00%
# Epoch: 12/20, Train Loss: 0.0071, Train Acc: 95.89%, Val Loss: 0.0500, Val Acc: 100.00%
# Epoch: 13/20, Train Loss: 0.0054, Train Acc: 97.26%, Val Loss: 0.0467, Val Acc: 100.00%
# Epoch: 14/20, Train Loss: 0.0050, Train Acc: 95.89%, Val Loss: 0.0765, Val Acc: 94.74%
# Epoch: 15/20, Train Loss: 0.0058, Train Acc: 97.26%, Val Loss: 0.0529, Val Acc: 100.00%
# Epoch: 16/20, Train Loss: 0.0055, Train Acc: 95.89%, Val Loss: 0.2897, Val Acc: 94.74%
# Epoch: 17/20, Train Loss: 0.0035, Train Acc: 97.26%, Val Loss: 0.0464, Val Acc: 100.00%
# Epoch: 18/20, Train Loss: 0.0068, Train Acc: 95.89%, Val Loss: 0.0602, Val Acc: 100.00%
# Epoch: 19/20, Train Loss: 0.0048, Train Acc: 95.89%, Val Loss: 0.0701, Val Acc: 100.00%
# Epoch: 20/20, Train Loss: 0.0033, Train Acc: 97.26%, Val Loss: 0.0356, Val Acc: 100.00%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/single-layer/SGD/model/gel_classifier-18.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/single-layer/SGD/plots/loss_accuracy_plots/gel_classifier-18.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('vgg16', 'single', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/single-layer/SGD/model/gel_classifier-18.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 18)
# Out:
# [INFO] Accuracy: 63.64%
# [INFO] Precision: 78.95%
# [INFO] Recall: 63.64%
# [INFO] Confusion matrix:
#  [[ 3  8]
#  [ 0 11]]
# [INFO] AUC: 63.64%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 18)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #2- Training the Model with Multiple Linear Layers as the Classifier Head

# %% [markdown]
# #a2- Optimization Algorithm: Adam

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=19 --hardware_type='tpu' --pretrained_model='vgg16' --classifier_head='multi' --opt_alg='adam' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/multi-layers/Adam/model/gel_classifier-19.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/multi-layers/Adam/plots/loss_accuracy_plots/gel_classifier-19.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.25, inplace=False)
#       (3): Linear(in_features=512, out_features=256, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.5, inplace=False)
#       (6): Linear(in_features=256, out_features=2, bias=True)
#     )
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0297, Train Acc: 52.05%, Val Loss: 0.3800, Val Acc: 84.21%
# Epoch: 2/20, Train Loss: 0.0094, Train Acc: 93.15%, Val Loss: 0.2871, Val Acc: 89.47%
# Epoch: 3/20, Train Loss: 0.0041, Train Acc: 95.89%, Val Loss: 0.2787, Val Acc: 94.74%
# Epoch: 4/20, Train Loss: 0.0048, Train Acc: 95.89%, Val Loss: 0.3069, Val Acc: 94.74%
# Epoch: 5/20, Train Loss: 0.0046, Train Acc: 97.26%, Val Loss: 0.2385, Val Acc: 94.74%
# Epoch: 6/20, Train Loss: 0.0014, Train Acc: 98.63%, Val Loss: 0.0145, Val Acc: 100.00%
# Epoch: 7/20, Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.1777, Val Acc: 94.74%
# Epoch: 8/20, Train Loss: 0.0035, Train Acc: 97.26%, Val Loss: 0.3603, Val Acc: 94.74%
# Epoch: 9/20, Train Loss: 0.0058, Train Acc: 97.26%, Val Loss: 0.3795, Val Acc: 94.74%
# Epoch: 10/20, Train Loss: 0.0050, Train Acc: 95.89%, Val Loss: 0.0102, Val Acc: 100.00%
# Epoch: 11/20, Train Loss: 0.0027, Train Acc: 97.26%, Val Loss: 0.1949, Val Acc: 94.74%
# Epoch: 12/20, Train Loss: 0.0016, Train Acc: 97.26%, Val Loss: 0.3348, Val Acc: 94.74%
# Epoch: 13/20, Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 0.0051, Val Acc: 100.00%
# Epoch: 14/20, Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 0.1775, Val Acc: 94.74%
# Epoch: 15/20, Train Loss: 0.0013, Train Acc: 98.63%, Val Loss: 0.3956, Val Acc: 94.74%
# Epoch: 16/20, Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.7046, Val Acc: 89.47%
# Epoch: 17/20, Train Loss: 0.0068, Train Acc: 97.26%, Val Loss: 0.4516, Val Acc: 94.74%
# Epoch: 18/20, Train Loss: 0.0028, Train Acc: 97.26%, Val Loss: 0.1723, Val Acc: 94.74%
# Epoch: 19/20, Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 0.1824, Val Acc: 94.74%
# Epoch: 20/20, Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 0.4284, Val Acc: 94.74%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/multi-layers/Adam/model/gel_classifier-19.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/multi-layers/Adam/plots/loss_accuracy_plots/gel_classifier-19.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('vgg16', 'multi', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/multi-layers/Adam/model/gel_classifier-19.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 19)
# Out:
# [INFO] Accuracy: 81.82%
# [INFO] Precision: 82.91%
# [INFO] Recall: 81.82%
# [INFO] Confusion matrix:
#  [[ 8  3]
#  [ 1 10]]
# [INFO] AUC: 81.82%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 19)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #b2- Optimization Algorithm: SGD

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=20 --hardware_type='tpu' --pretrained_model='vgg16' --classifier_head='multi' --opt_alg='sgd' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/multi-layers/SGD/model/gel_classifier-20.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/multi-layers/SGD/plots/loss_accuracy_plots/gel_classifier-20.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.25, inplace=False)
#       (3): Linear(in_features=512, out_features=256, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.5, inplace=False)
#       (6): Linear(in_features=256, out_features=2, bias=True)
#     )
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0381, Train Acc: 50.68%, Val Loss: 0.6908, Val Acc: 63.16%
# Epoch: 2/20, Train Loss: 0.0379, Train Acc: 43.84%, Val Loss: 0.6866, Val Acc: 68.42%
# Epoch: 3/20, Train Loss: 0.0379, Train Acc: 61.64%, Val Loss: 0.6839, Val Acc: 100.00%
# Epoch: 4/20, Train Loss: 0.0376, Train Acc: 60.27%, Val Loss: 0.6820, Val Acc: 84.21%
# Epoch: 5/20, Train Loss: 0.0373, Train Acc: 68.49%, Val Loss: 0.6784, Val Acc: 89.47%
# Epoch: 6/20, Train Loss: 0.0369, Train Acc: 71.23%, Val Loss: 0.6727, Val Acc: 84.21%
# Epoch: 7/20, Train Loss: 0.0369, Train Acc: 72.60%, Val Loss: 0.6677, Val Acc: 84.21%
# Epoch: 8/20, Train Loss: 0.0367, Train Acc: 78.08%, Val Loss: 0.6665, Val Acc: 78.95%
# Epoch: 9/20, Train Loss: 0.0357, Train Acc: 82.19%, Val Loss: 0.6587, Val Acc: 84.21%
# Epoch: 10/20, Train Loss: 0.0361, Train Acc: 78.08%, Val Loss: 0.6463, Val Acc: 84.21%
# Epoch: 11/20, Train Loss: 0.0359, Train Acc: 82.19%, Val Loss: 0.6448, Val Acc: 84.21%
# Epoch: 12/20, Train Loss: 0.0356, Train Acc: 89.04%, Val Loss: 0.6296, Val Acc: 89.47%
# Epoch: 13/20, Train Loss: 0.0345, Train Acc: 89.04%, Val Loss: 0.6263, Val Acc: 84.21%
# Epoch: 14/20, Train Loss: 0.0348, Train Acc: 89.04%, Val Loss: 0.6013, Val Acc: 94.74%
# Epoch: 15/20, Train Loss: 0.0335, Train Acc: 94.52%, Val Loss: 0.5939, Val Acc: 94.74%
# Epoch: 16/20, Train Loss: 0.0339, Train Acc: 87.67%, Val Loss: 0.5790, Val Acc: 100.00%
# Epoch: 17/20, Train Loss: 0.0329, Train Acc: 95.89%, Val Loss: 0.5614, Val Acc: 94.74%
# Epoch: 18/20, Train Loss: 0.0314, Train Acc: 91.78%, Val Loss: 0.5440, Val Acc: 94.74%
# Epoch: 19/20, Train Loss: 0.0306, Train Acc: 91.78%, Val Loss: 0.5227, Val Acc: 100.00%
# Epoch: 20/20, Train Loss: 0.0306, Train Acc: 93.15%, Val Loss: 0.5137, Val Acc: 94.74%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/multi-layers/SGD/model/gel_classifier-20.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/multi-layers/SGD/plots/loss_accuracy_plots/gel_classifier-20.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('vgg16', 'multi', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/TPU/VGG16/multi-layers/SGD/model/gel_classifier-20.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 20)
# Out:
# [INFO] Accuracy: 86.36%
# [INFO] Precision: 89.29%
# [INFO] Recall: 86.36%
# [INFO] Confusion matrix:
#  [[ 8  3]
#  [ 0 11]]
# [INFO] AUC: 86.36%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv
