# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Gel_Project_Image_Classification
# Out:
# /content/drive/MyDrive/Gel_Project_Image_Classification

# %% [markdown]
# #1- Training the Model with a Single Linear Layer as the Classifier Head (single for shortcut)

# %% [markdown]
# #a1- Optimization Algorithm: Adam

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=17 --hardware_type='gpu' --pretrained_model='vgg16' --classifier_head='single' --opt_alg='adam' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/single-layer/Adam/model/gel_classifier-17.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/single-layer/Adam/plots/loss_accuracy_plots/gel_classifier-17.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:05<00:00, 107MB/s]
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0355, Train Acc: 61.64%, Val Loss: 0.5207, Val Acc: 78.95%
# Epoch: 2/20, Train Loss: 0.0260, Train Acc: 82.19%, Val Loss: 0.4018, Val Acc: 78.95%
# Epoch: 3/20, Train Loss: 0.0171, Train Acc: 89.04%, Val Loss: 0.3834, Val Acc: 84.21%
# Epoch: 4/20, Train Loss: 0.0183, Train Acc: 90.41%, Val Loss: 0.3959, Val Acc: 78.95%
# Epoch: 5/20, Train Loss: 0.0091, Train Acc: 95.89%, Val Loss: 0.4442, Val Acc: 73.68%
# Epoch: 6/20, Train Loss: 0.0134, Train Acc: 93.15%, Val Loss: 0.2296, Val Acc: 89.47%
# Epoch: 7/20, Train Loss: 0.0055, Train Acc: 97.26%, Val Loss: 0.1458, Val Acc: 94.74%
# Epoch: 8/20, Train Loss: 0.0193, Train Acc: 91.78%, Val Loss: 0.3333, Val Acc: 84.21%
# Epoch: 9/20, Train Loss: 0.0115, Train Acc: 98.63%, Val Loss: 0.1629, Val Acc: 94.74%
# Epoch: 10/20, Train Loss: 0.0056, Train Acc: 97.26%, Val Loss: 0.1593, Val Acc: 94.74%
# Epoch: 11/20, Train Loss: 0.0043, Train Acc: 97.26%, Val Loss: 0.0954, Val Acc: 100.00%
# Epoch: 12/20, Train Loss: 0.0040, Train Acc: 98.63%, Val Loss: 0.1404, Val Acc: 94.74%
# Epoch: 13/20, Train Loss: 0.0048, Train Acc: 98.63%, Val Loss: 0.1314, Val Acc: 94.74%
# Epoch: 14/20, Train Loss: 0.0028, Train Acc: 100.00%, Val Loss: 0.3146, Val Acc: 89.47%
# Epoch: 15/20, Train Loss: 0.0040, Train Acc: 97.26%, Val Loss: 0.1618, Val Acc: 89.47%
# Epoch: 16/20, Train Loss: 0.0019, Train Acc: 100.00%, Val Loss: 0.1604, Val Acc: 89.47%
# Epoch: 17/20, Train Loss: 0.0064, Train Acc: 97.26%, Val Loss: 0.3401, Val Acc: 89.47%
# Epoch: 18/20, Train Loss: 0.0029, Train Acc: 98.63%, Val Loss: 0.1752, Val Acc: 89.47%
# Epoch: 19/20, Train Loss: 0.0050, Train Acc: 98.63%, Val Loss: 0.3027, Val Acc: 84.21%
# Epoch: 20/20, Train Loss: 0.0043, Train Acc: 98.63%, Val Loss: 0.0651, Val Acc: 100.00%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/single-layer/Adam/model/gel_classifier-17.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/single-layer/Adam/plots/loss_accuracy_plots/gel_classifier-17.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# # Import the necessary libraries

# %%
import os
import time
import torch
import pandas as pd
import seaborn as sns
from PIL import Image
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, auc
import utils
import build_dataset
import prepare_model

# %% [markdown]
# #Loading and Preparing Test Dataset

# %%
# Load the test images
test_images = '/content/drive/MyDrive/Gel_Project_Image_Classification/test_images'

# Create a test dataset
test_dataset = build_dataset.GelElectrophoresisDataset(test_images, transform=utils.test_transform)

# Get the number of classes
num_classes = test_dataset.num_classes

# Create dataloader on test images
test_dataloader = DataLoader(test_dataset, batch_size=23, shuffle=False, num_workers=2)

# %% [markdown]
# #Loading The Model

# %%
def load_model(pretrained_model, classifier_head, hardware_type, num_classes, model_path):

    if pretrained_model == 'resnet18':
        model = prepare_model.resnet18(num_classes, classifier_head)
    elif pretrained_model == 'vgg16':
        model = prepare_model.vgg16(num_classes, classifier_head)
    elif pretrained_model == 'mobilenet-v3':
        model = prepare_model.mobilenet_v3(num_classes, classifier_head)
    else:
        raise ValueError("Invalid pretrained model")

    # Load the trained weights of the model from a saved checkpoint file
    model.load_state_dict(torch.load(model_path))

    print("[INFO] Loading the model...")

    # Choose the device to run inference on
    if hardware_type == 'gpu':
        if torch.cuda.is_available():
            device = torch.device('cuda')
        else:
            raise ValueError("GPU is not available. Please select 'cpu' as the hardware type.")
    elif hardware_type == 'cpu':
        device = torch.device('cpu')
    else:
        raise ValueError("Invalid hardware type. Please select either 'cpu' or 'gpu'.")

    # Move the model to the device
    model = model.to(device)

    # Set the model to evaluation mode
    model.eval()

    print("[INFO] Model loaded!")

    # Return the loaded model and device
    return model, device

# %%
model, device=load_model('vgg16', 'single','gpu', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/single-layer/Adam/model/gel_classifier-17.pth')
# Out:
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
def evaluate_metrics(model, device, test_dataloader, model_id):

    # Testing loop
    predictions = []
    targets = []

    # Disables gradient calculation (as gradients are not needed during evaluation)
    with torch.no_grad():
      for inputs, labels in test_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())
        targets.extend(labels.cpu().numpy())

    # Calculate evaluation metrics
    accuracy = accuracy_score(targets, predictions)
    precision = precision_score(targets, predictions, average='weighted')
    recall = recall_score(targets, predictions, average='weighted')
    conf_mat = confusion_matrix(targets, predictions)
    fpr, tpr, thresholds = roc_curve(targets, predictions)
    roc_auc = auc(fpr, tpr)
    print('[INFO] Accuracy: {:.2f}%'.format(accuracy*100))
    print('[INFO] Precision: {:.2f}%'.format(precision*100))
    print('[INFO] Recall: {:.2f}%'.format(recall*100))
    print('[INFO] Confusion matrix:\n', conf_mat)
    print('[INFO] AUC: {:.2f}%'.format(roc_auc*100))

    # Plot confusion matrix
    plt.figure(figsize=(4, 3))
    sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues')
    plt.title('ConfusionMatrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    # Plot ROC curve
    plt.figure(figsize=(4, 3))
    plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = {:.2f}%)'.format(roc_auc*100))
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.show()

    # Store the evaluation metrics in a dictionary
    results = {
        'model_id': model_id,
        'accuracy': '{:.2f}%'.format(accuracy*100),
        'precision': '{:.2f}%'.format(precision*100),
        'recall': '{:.2f}%'.format(recall*100),
        'conf_mat': str(conf_mat.tolist()),
        'roc_auc': '{:.2f}%'.format(roc_auc*100)

    }

    return results

# %%
results = evaluate_metrics(model, device, test_dataloader, 17)
# Out:
# [INFO] Accuracy: 72.73%
# [INFO] Precision: 82.35%
# [INFO] Recall: 72.73%
# [INFO] Confusion matrix:
#  [[ 5  6]
#  [ 0 11]]
# [INFO] AUC: 72.73%

# %%
# Path to results CSV file
results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
def inference(model, device, test_dataloader, test_dataset, model_id):
    # Start inference timer
    inf_start = time.time()

    # Testing loop
    predictions = []
    correct = 0
    total = 0

    # Disables gradient calculation (as gradients are not needed during inference)
    with torch.no_grad():
        for inputs, labels in test_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            predictions.extend(predicted.cpu().numpy())

            # Display images with predicted and actual classes
            for j in range(len(labels)):
                # Get image name and path
                image_path = test_dataset.samples[j][0]
                image_name = os.path.basename(image_path)
                # Load and display image
                img = Image.open(image_path)
                plt.imshow(img, cmap='gray')
                plt.axis('off')
                plt.title(f'Predicted: {test_dataset.image_folder.classes[predictions[j]]}, Actual: {test_dataset.image_folder.classes[labels[j]]}')
                plt.show()

    # End inference timer
    inf_end = time.time()
    # Calculate inference time
    inf_time_secs = inf_end - inf_start
    # Convert seconds to minutes
    inf_time_mins = inf_time_secs / 60
    print("[INFO] Inference completed on test samples")
    # Print total inference time
    print(f"[INFO] Total inference time: {inf_time_secs:.2f} seconds, {inf_time_mins:.2f} minutes")

    # Store inference time in a dictionary
    results = {
      'model_id': model_id,
      'inference_time_secs': inf_time_secs
    }

    return results

# %%
results = inference(model, device, test_dataloader, test_dataset, 17)

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #b1- Optimization Algorithm: SGD

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=18 --hardware_type='gpu' --pretrained_model='vgg16' --classifier_head='single' --opt_alg='sgd' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/single-layer/SGD/model/gel_classifier-18.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/single-layer/SGD/plots/loss_accuracy_plots/gel_classifier-18.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0379, Train Acc: 52.05%, Val Loss: 0.5512, Val Acc: 89.47%
# Epoch: 2/20, Train Loss: 0.0281, Train Acc: 82.19%, Val Loss: 0.3737, Val Acc: 89.47%
# Epoch: 3/20, Train Loss: 0.0205, Train Acc: 93.15%, Val Loss: 0.2929, Val Acc: 89.47%
# Epoch: 4/20, Train Loss: 0.0116, Train Acc: 91.78%, Val Loss: 0.2491, Val Acc: 89.47%
# Epoch: 5/20, Train Loss: 0.0126, Train Acc: 91.78%, Val Loss: 0.3165, Val Acc: 84.21%
# Epoch: 6/20, Train Loss: 0.0084, Train Acc: 95.89%, Val Loss: 0.3212, Val Acc: 89.47%
# Epoch: 7/20, Train Loss: 0.0073, Train Acc: 94.52%, Val Loss: 0.2167, Val Acc: 89.47%
# Epoch: 8/20, Train Loss: 0.0058, Train Acc: 95.89%, Val Loss: 0.2974, Val Acc: 89.47%
# Epoch: 9/20, Train Loss: 0.0099, Train Acc: 91.78%, Val Loss: 0.2488, Val Acc: 84.21%
# Epoch: 10/20, Train Loss: 0.0074, Train Acc: 93.15%, Val Loss: 0.2040, Val Acc: 89.47%
# Epoch: 11/20, Train Loss: 0.0081, Train Acc: 93.15%, Val Loss: 0.1989, Val Acc: 89.47%
# Epoch: 12/20, Train Loss: 0.0069, Train Acc: 95.89%, Val Loss: 0.2702, Val Acc: 89.47%
# Epoch: 13/20, Train Loss: 0.0077, Train Acc: 91.78%, Val Loss: 0.3463, Val Acc: 84.21%
# Epoch: 14/20, Train Loss: 0.0086, Train Acc: 94.52%, Val Loss: 0.1416, Val Acc: 94.74%
# Epoch: 15/20, Train Loss: 0.0067, Train Acc: 95.89%, Val Loss: 0.2284, Val Acc: 89.47%
# Epoch: 16/20, Train Loss: 0.0082, Train Acc: 94.52%, Val Loss: 0.1554, Val Acc: 89.47%
# Epoch: 17/20, Train Loss: 0.0064, Train Acc: 94.52%, Val Loss: 0.0912, Val Acc: 94.74%
# Epoch: 18/20, Train Loss: 0.0068, Train Acc: 91.78%, Val Loss: 0.1498, Val Acc: 94.74%
# Epoch: 19/20, Train Loss: 0.0080, Train Acc: 93.15%, Val Loss: 0.2328, Val Acc: 84.21%
# Epoch: 20/20, Train Loss: 0.0117, Train Acc: 94.52%, Val Loss: 0.3288, Val Acc: 84.21%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/single-layer/SGD/model/gel_classifier-18.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/single-layer/SGD/plots/loss_accuracy_plots/gel_classifier-18.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('vgg16', 'single','gpu', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/single-layer/SGD/model/gel_classifier-18.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 18)
# Out:
# [INFO] Accuracy: 77.27%
# [INFO] Precision: 79.46%
# [INFO] Recall: 77.27%
# [INFO] Confusion matrix:
#  [[ 7  4]
#  [ 1 10]]
# [INFO] AUC: 77.27%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 18)

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #2- Training the Model with a Sequential Multi-Layer as the Classifier Head (multi for shortcut)

# %% [markdown]
# #a2- Optimization Algorithm: Adam

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=19 --hardware_type='gpu' --pretrained_model='vgg16' --classifier_head='multi' --opt_alg='adam' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/multi-layers/Adam/model/gel_classifier-19.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/multi-layers/Adam/plots/loss_accuracy_plots/gel_classifier-19.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.25, inplace=False)
#       (3): Linear(in_features=512, out_features=256, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.5, inplace=False)
#       (6): Linear(in_features=256, out_features=2, bias=True)
#     )
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0283, Train Acc: 71.23%, Val Loss: 0.3784, Val Acc: 89.47%
# Epoch: 2/20, Train Loss: 0.0116, Train Acc: 94.52%, Val Loss: 0.3252, Val Acc: 89.47%
# Epoch: 3/20, Train Loss: 0.0146, Train Acc: 89.04%, Val Loss: 0.0970, Val Acc: 94.74%
# Epoch: 4/20, Train Loss: 0.0024, Train Acc: 98.63%, Val Loss: 0.6105, Val Acc: 84.21%
# Epoch: 5/20, Train Loss: 0.0039, Train Acc: 95.89%, Val Loss: 0.3571, Val Acc: 89.47%
# Epoch: 6/20, Train Loss: 0.0050, Train Acc: 97.26%, Val Loss: 0.2848, Val Acc: 94.74%
# Epoch: 7/20, Train Loss: 0.0028, Train Acc: 97.26%, Val Loss: 0.2352, Val Acc: 94.74%
# Epoch: 8/20, Train Loss: 0.0066, Train Acc: 93.15%, Val Loss: 0.3117, Val Acc: 94.74%
# Epoch: 9/20, Train Loss: 0.0013, Train Acc: 100.00%, Val Loss: 0.3225, Val Acc: 94.74%
# Epoch: 10/20, Train Loss: 0.0009, Train Acc: 100.00%, Val Loss: 0.3405, Val Acc: 94.74%
# Epoch: 11/20, Train Loss: 0.0017, Train Acc: 98.63%, Val Loss: 0.5062, Val Acc: 89.47%
# Epoch: 12/20, Train Loss: 0.0058, Train Acc: 95.89%, Val Loss: 0.2662, Val Acc: 94.74%
# Epoch: 13/20, Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 0.2001, Val Acc: 89.47%
# Epoch: 14/20, Train Loss: 0.0026, Train Acc: 95.89%, Val Loss: 0.3387, Val Acc: 94.74%
# Epoch: 15/20, Train Loss: 0.0013, Train Acc: 98.63%, Val Loss: 0.3646, Val Acc: 94.74%
# Epoch: 16/20, Train Loss: 0.0093, Train Acc: 94.52%, Val Loss: 0.7276, Val Acc: 89.47%
# Epoch: 17/20, Train Loss: 0.0058, Train Acc: 97.26%, Val Loss: 0.1462, Val Acc: 94.74%
# Epoch: 18/20, Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 0.2581, Val Acc: 89.47%
# Epoch: 19/20, Train Loss: 0.0009, Train Acc: 100.00%, Val Loss: 0.3383, Val Acc: 94.74%
# Epoch: 20/20, Train Loss: 0.0056, Train Acc: 95.89%, Val Loss: 0.4550, Val Acc: 89.47%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/multi-layers/Adam/model/gel_classifier-19.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/multi-layers/Adam/plots/loss_accuracy_plots/gel_classifier-19.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('vgg16', 'multi', 'gpu', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/multi-layers/Adam/model/gel_classifier-19.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 19)
# Out:
# [INFO] Accuracy: 77.27%
# [INFO] Precision: 84.38%
# [INFO] Recall: 77.27%
# [INFO] Confusion matrix:
#  [[ 6  5]
#  [ 0 11]]
# [INFO] AUC: 77.27%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 19)

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #b2- Optimization Algorithm: SGD

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=20 --hardware_type='gpu' --pretrained_model='vgg16' --classifier_head='multi' --opt_alg='sgd' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/multi-layers/SGD/model/gel_classifier-20.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/multi-layers/SGD/plots/loss_accuracy_plots/gel_classifier-20.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.25, inplace=False)
#       (3): Linear(in_features=512, out_features=256, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.5, inplace=False)
#       (6): Linear(in_features=256, out_features=2, bias=True)
#     )
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0377, Train Acc: 49.32%, Val Loss: 0.6822, Val Acc: 63.16%
# Epoch: 2/20, Train Loss: 0.0375, Train Acc: 46.58%, Val Loss: 0.6763, Val Acc: 63.16%
# Epoch: 3/20, Train Loss: 0.0386, Train Acc: 52.05%, Val Loss: 0.6742, Val Acc: 63.16%
# Epoch: 4/20, Train Loss: 0.0374, Train Acc: 57.53%, Val Loss: 0.6698, Val Acc: 94.74%
# Epoch: 5/20, Train Loss: 0.0370, Train Acc: 67.12%, Val Loss: 0.6597, Val Acc: 94.74%
# Epoch: 6/20, Train Loss: 0.0366, Train Acc: 75.34%, Val Loss: 0.6493, Val Acc: 89.47%
# Epoch: 7/20, Train Loss: 0.0360, Train Acc: 72.60%, Val Loss: 0.6433, Val Acc: 94.74%
# Epoch: 8/20, Train Loss: 0.0351, Train Acc: 73.97%, Val Loss: 0.6354, Val Acc: 89.47%
# Epoch: 9/20, Train Loss: 0.0346, Train Acc: 80.82%, Val Loss: 0.6346, Val Acc: 73.68%
# Epoch: 10/20, Train Loss: 0.0340, Train Acc: 80.82%, Val Loss: 0.6262, Val Acc: 84.21%
# Epoch: 11/20, Train Loss: 0.0337, Train Acc: 79.45%, Val Loss: 0.6100, Val Acc: 84.21%
# Epoch: 12/20, Train Loss: 0.0341, Train Acc: 80.82%, Val Loss: 0.6114, Val Acc: 84.21%
# Epoch: 13/20, Train Loss: 0.0330, Train Acc: 86.30%, Val Loss: 0.5912, Val Acc: 73.68%
# Epoch: 14/20, Train Loss: 0.0307, Train Acc: 82.19%, Val Loss: 0.5594, Val Acc: 84.21%
# Epoch: 15/20, Train Loss: 0.0314, Train Acc: 80.82%, Val Loss: 0.5846, Val Acc: 78.95%
# Epoch: 16/20, Train Loss: 0.0295, Train Acc: 86.30%, Val Loss: 0.5475, Val Acc: 84.21%
# Epoch: 17/20, Train Loss: 0.0304, Train Acc: 87.67%, Val Loss: 0.5392, Val Acc: 84.21%
# Epoch: 18/20, Train Loss: 0.0303, Train Acc: 82.19%, Val Loss: 0.5240, Val Acc: 84.21%
# Epoch: 19/20, Train Loss: 0.0270, Train Acc: 90.41%, Val Loss: 0.4674, Val Acc: 94.74%
# Epoch: 20/20, Train Loss: 0.0275, Train Acc: 89.04%, Val Loss: 0.4486, Val Acc: 89.47%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/multi-layers/SGD/model/gel_classifier-20.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/multi-layers/SGD/plots/loss_accuracy_plots/gel_classifier-20.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('vgg16', 'multi', 'gpu', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/GPU/VGG16/multi-layers/SGD/model/gel_classifier-20.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 20)
# Out:
# [INFO] Accuracy: 77.27%
# [INFO] Precision: 79.46%
# [INFO] Recall: 77.27%
# [INFO] Confusion matrix:
#  [[ 7  4]
#  [ 1 10]]
# [INFO] AUC: 77.27%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 20)
# Out:
# [INFO] Inference completed on test samples
# [INFO] Total inference time: 6.44 seconds, 0.11 minutes

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv
