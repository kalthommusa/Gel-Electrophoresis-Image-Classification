# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Gel_Project_Image_Classification
# Out:
# /content/drive/MyDrive/Gel_Project_Image_Classification

# %% [markdown]
# #1- Training the Model with a Single Linear Layer as the Classifier Head

# %% [markdown]
# #a1- Optimization Algorithm: Adam

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=5 --hardware_type='cpu' --pretrained_model='vgg16' --classifier_head='single' --opt_alg='adam' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/single-layer/Adam/model/gel_classifier-5.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/single-layer/Adam/plots/loss_accuracy_plots/gel_classifier-5.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:04<00:00, 131MB/s]
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0337, Train Acc: 60.27%, Val Loss: 0.4271, Val Acc: 94.74%
# Epoch: 2/20, Train Loss: 0.0183, Train Acc: 98.63%, Val Loss: 0.3415, Val Acc: 89.47%
# Epoch: 3/20, Train Loss: 0.0102, Train Acc: 97.26%, Val Loss: 0.2591, Val Acc: 89.47%
# Epoch: 4/20, Train Loss: 0.0077, Train Acc: 97.26%, Val Loss: 0.2538, Val Acc: 89.47%
# Epoch: 5/20, Train Loss: 0.0046, Train Acc: 98.63%, Val Loss: 0.3033, Val Acc: 89.47%
# Epoch: 6/20, Train Loss: 0.0054, Train Acc: 97.26%, Val Loss: 0.3681, Val Acc: 89.47%
# Epoch: 7/20, Train Loss: 0.0062, Train Acc: 94.52%, Val Loss: 0.1267, Val Acc: 94.74%
# Epoch: 8/20, Train Loss: 0.0019, Train Acc: 100.00%, Val Loss: 0.2251, Val Acc: 89.47%
# Epoch: 9/20, Train Loss: 0.0015, Train Acc: 100.00%, Val Loss: 0.3056, Val Acc: 84.21%
# Epoch: 10/20, Train Loss: 0.0016, Train Acc: 100.00%, Val Loss: 0.4178, Val Acc: 94.74%
# Epoch: 11/20, Train Loss: 0.0053, Train Acc: 97.26%, Val Loss: 0.1095, Val Acc: 94.74%
# Epoch: 12/20, Train Loss: 0.0042, Train Acc: 95.89%, Val Loss: 0.1282, Val Acc: 94.74%
# Epoch: 13/20, Train Loss: 0.0037, Train Acc: 95.89%, Val Loss: 0.1685, Val Acc: 94.74%
# Epoch: 14/20, Train Loss: 0.0022, Train Acc: 97.26%, Val Loss: 0.2384, Val Acc: 89.47%
# Epoch: 15/20, Train Loss: 0.0022, Train Acc: 98.63%, Val Loss: 0.1714, Val Acc: 89.47%
# Epoch: 16/20, Train Loss: 0.0013, Train Acc: 100.00%, Val Loss: 0.3320, Val Acc: 89.47%
# Epoch: 17/20, Train Loss: 0.0013, Train Acc: 98.63%, Val Loss: 0.3152, Val Acc: 84.21%
# Epoch: 18/20, Train Loss: 0.0082, Train Acc: 95.89%, Val Loss: 0.0785, Val Acc: 100.00%
# Epoch: 19/20, Train Loss: 0.0013, Train Acc: 98.63%, Val Loss: 0.4075, Val Acc: 84.21%
# Epoch: 20/20, Train Loss: 0.0012, Train Acc: 100.00%, Val Loss: 0.1679, Val Acc: 94.74%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/single-layer/Adam/model/gel_classifier-5.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/single-layer/Adam/plots/loss_accuracy_plots/gel_classifier-5.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# # Import the necessary libraries

# %%
import os
import time
import torch
import pandas as pd
import seaborn as sns
from PIL import Image
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, auc
import utils
import build_dataset
import prepare_model

# %% [markdown]
# #Loading and Preparing Test Dataset

# %%
# Load the test images
test_images = '/content/drive/MyDrive/Gel_Project_Image_Classification/test_images'

# Create a test dataset
test_dataset = build_dataset.GelElectrophoresisDataset(test_images, transform=utils.test_transform)

# Get the number of classes
num_classes = test_dataset.num_classes

# Create dataloader on test images
test_dataloader = DataLoader(test_dataset, batch_size=23, shuffle=False, num_workers=2)

# %% [markdown]
# #Loading The Model

# %%
def load_model(pretrained_model, classifier_head, num_classes, model_path):

    if pretrained_model == 'resnet18':
        model = prepare_model.resnet18(num_classes, classifier_head)
    elif pretrained_model == 'vgg16':
        model = prepare_model.vgg16(num_classes, classifier_head)
    elif pretrained_model == 'mobilenet-v3':
        model = prepare_model.mobilenet_v3(num_classes, classifier_head)
    else:
        raise ValueError("Invalid pretrained model")

    # Load the trained weights of the model from a saved checkpoint file
    model.load_state_dict(torch.load(model_path))

    print("[INFO] Loading the model...")

    # Choose the device to run inference on (GPU if available, else CPU)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    # Move the model to the device
    model = model.to(device)

    # Set the model to evaluation mode
    model.eval()

    print("[INFO] Model loaded!")

    # Return the loaded model and device
    return model, device

# %%
model, device=load_model('vgg16', 'single', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/single-layer/Adam/model/gel_classifier-5.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
def evaluate_metrics(model, device, test_dataloader, model_id):

    # Testing loop
    predictions = []
    targets = []

    # Disables gradient calculation (as gradients are not needed during evaluation)
    with torch.no_grad():
      for inputs, labels in test_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())
        targets.extend(labels.cpu().numpy())

    # Calculate evaluation metrics
    accuracy = accuracy_score(targets, predictions)
    precision = precision_score(targets, predictions, average='weighted')
    recall = recall_score(targets, predictions, average='weighted')
    conf_mat = confusion_matrix(targets, predictions)
    fpr, tpr, thresholds = roc_curve(targets, predictions)
    roc_auc = auc(fpr, tpr)
    print('[INFO] Accuracy: {:.2f}%'.format(accuracy*100))
    print('[INFO] Precision: {:.2f}%'.format(precision*100))
    print('[INFO] Recall: {:.2f}%'.format(recall*100))
    print('[INFO] Confusion matrix:\n', conf_mat)
    print('[INFO] AUC: {:.2f}%'.format(roc_auc*100))

    # Plot confusion matrix
    plt.figure(figsize=(4, 3))
    sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues')
    plt.title('ConfusionMatrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    # Plot ROC curve
    plt.figure(figsize=(4, 3))
    plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = {:.2f}%)'.format(roc_auc*100))
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.show()

    # Store the evaluation metrics in a dictionary
    results = {
        'model_id': model_id,
        'accuracy': '{:.2f}%'.format(accuracy*100),
        'precision': '{:.2f}%'.format(precision*100),
        'recall': '{:.2f}%'.format(recall*100),
        'conf_mat': str(conf_mat.tolist()),
        'roc_auc': '{:.2f}%'.format(roc_auc*100)

    }

    return results

# %%
results = evaluate_metrics(model, device, test_dataloader, 5)
# Out:
# [INFO] Accuracy: 68.18%
# [INFO] Precision: 80.56%
# [INFO] Recall: 68.18%
# [INFO] Confusion matrix:
#  [[ 4  7]
#  [ 0 11]]
# [INFO] AUC: 68.18%

# %%
# Path to results CSV file
results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
def inference(model, device, test_dataloader, test_dataset, model_id):
    # Start inference timer
    inf_start = time.time()

    # Testing loop
    predictions = []
    correct = 0
    total = 0

    # Disables gradient calculation (as gradients are not needed during inference)
    with torch.no_grad():
        for inputs, labels in test_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            predictions.extend(predicted.cpu().numpy())

            # Display images with predicted and actual classes
            for j in range(len(labels)):
                # Get image name and path
                image_path = test_dataset.samples[j][0]
                image_name = os.path.basename(image_path)
                # Load and display image
                img = Image.open(image_path)
                plt.imshow(img, cmap='gray')
                plt.axis('off')
                plt.title(f'Predicted: {test_dataset.image_folder.classes[predictions[j]]}, Actual: {test_dataset.image_folder.classes[labels[j]]}')
                plt.show()

    # End inference timer
    inf_end = time.time()
    # Calculate inference time
    inf_time_secs = inf_end - inf_start
    # Convert seconds to minutes
    inf_time_mins = inf_time_secs / 60
    print("[INFO] Inference completed on test samples")
    # Print total inference time
    print(f"[INFO] Total inference time: {inf_time_secs:.2f} seconds, {inf_time_mins:.2f} minutes")

    # Store inference time in a dictionary
    results = {
      'model_id': model_id,
      'inference_time_secs': inf_time_secs
    }

    return results

# %%
results = inference(model, device, test_dataloader, test_dataset, 5)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #b1- Optimization Algorithm: SGD

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=6 --hardware_type='cpu' --pretrained_model='vgg16' --classifier_head='single' --opt_alg='sgd' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/single-layer/SGD/model/gel_classifier-6.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/single-layer/SGD/plots/loss_accuracy_plots/gel_classifier-6.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0326, Train Acc: 72.60%, Val Loss: 0.4886, Val Acc: 89.47%
# Epoch: 2/20, Train Loss: 0.0244, Train Acc: 86.30%, Val Loss: 0.2569, Val Acc: 100.00%
# Epoch: 3/20, Train Loss: 0.0186, Train Acc: 91.78%, Val Loss: 0.2092, Val Acc: 94.74%
# Epoch: 4/20, Train Loss: 0.0123, Train Acc: 90.41%, Val Loss: 0.1657, Val Acc: 94.74%
# Epoch: 5/20, Train Loss: 0.0088, Train Acc: 94.52%, Val Loss: 0.1340, Val Acc: 94.74%
# Epoch: 6/20, Train Loss: 0.0077, Train Acc: 95.89%, Val Loss: 0.1450, Val Acc: 94.74%
# Epoch: 7/20, Train Loss: 0.0067, Train Acc: 94.52%, Val Loss: 0.0542, Val Acc: 100.00%
# Epoch: 8/20, Train Loss: 0.0056, Train Acc: 97.26%, Val Loss: 0.1283, Val Acc: 94.74%
# Epoch: 9/20, Train Loss: 0.0050, Train Acc: 94.52%, Val Loss: 0.0747, Val Acc: 100.00%
# Epoch: 10/20, Train Loss: 0.0115, Train Acc: 91.78%, Val Loss: 0.0978, Val Acc: 100.00%
# Epoch: 11/20, Train Loss: 0.0115, Train Acc: 94.52%, Val Loss: 0.0964, Val Acc: 94.74%
# Epoch: 12/20, Train Loss: 0.0107, Train Acc: 93.15%, Val Loss: 0.1441, Val Acc: 94.74%
# Epoch: 13/20, Train Loss: 0.0028, Train Acc: 98.63%, Val Loss: 0.0905, Val Acc: 94.74%
# Epoch: 14/20, Train Loss: 0.0066, Train Acc: 94.52%, Val Loss: 0.0773, Val Acc: 100.00%
# Epoch: 15/20, Train Loss: 0.0060, Train Acc: 95.89%, Val Loss: 0.0599, Val Acc: 100.00%
# Epoch: 16/20, Train Loss: 0.0054, Train Acc: 97.26%, Val Loss: 0.0760, Val Acc: 100.00%
# Epoch: 17/20, Train Loss: 0.0072, Train Acc: 94.52%, Val Loss: 0.0761, Val Acc: 100.00%
# Epoch: 18/20, Train Loss: 0.0042, Train Acc: 95.89%, Val Loss: 0.1314, Val Acc: 94.74%
# Epoch: 19/20, Train Loss: 0.0189, Train Acc: 94.52%, Val Loss: 0.1715, Val Acc: 94.74%
# Epoch: 20/20, Train Loss: 0.0074, Train Acc: 95.89%, Val Loss: 0.0811, Val Acc: 100.00%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/single-layer/SGD/model/gel_classifier-6.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/single-layer/SGD/plots/loss_accuracy_plots/gel_classifier-6.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('vgg16', 'single', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/single-layer/SGD/model/gel_classifier-6.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 6)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [INFO] Accuracy: 50.00%
# [INFO] Precision: 25.00%
# [INFO] Recall: 50.00%
# [INFO] Confusion matrix:
#  [[ 0 11]
#  [ 0 11]]
# [INFO] AUC: 50.00%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 6)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #2- Training the Model with Multiple Linear Layers as the Classifier Head

# %% [markdown]
# #a2- Optimization Algorithm: Adam

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=7 --hardware_type='cpu' --pretrained_model='vgg16' --classifier_head='multi' --opt_alg='adam' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/multi-layers/Adam/model/gel_classifier-7.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/multi-layers/Adam/plots/loss_accuracy_plots/gel_classifier-7.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.25, inplace=False)
#       (3): Linear(in_features=512, out_features=256, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.5, inplace=False)
#       (6): Linear(in_features=256, out_features=2, bias=True)
#     )
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0368, Train Acc: 50.68%, Val Loss: 0.4576, Val Acc: 100.00%
# Epoch: 2/20, Train Loss: 0.0250, Train Acc: 86.30%, Val Loss: 0.2258, Val Acc: 94.74%
# Epoch: 3/20, Train Loss: 0.0116, Train Acc: 93.15%, Val Loss: 0.1304, Val Acc: 94.74%
# Epoch: 4/20, Train Loss: 0.0115, Train Acc: 91.78%, Val Loss: 0.0374, Val Acc: 100.00%
# Epoch: 5/20, Train Loss: 0.0047, Train Acc: 95.89%, Val Loss: 0.1665, Val Acc: 94.74%
# Epoch: 6/20, Train Loss: 0.0031, Train Acc: 98.63%, Val Loss: 0.0141, Val Acc: 100.00%
# Epoch: 7/20, Train Loss: 0.0065, Train Acc: 95.89%, Val Loss: 0.3766, Val Acc: 94.74%
# Epoch: 8/20, Train Loss: 0.0105, Train Acc: 93.15%, Val Loss: 0.0309, Val Acc: 100.00%
# Epoch: 9/20, Train Loss: 0.0078, Train Acc: 94.52%, Val Loss: 0.0137, Val Acc: 100.00%
# Epoch: 10/20, Train Loss: 0.0056, Train Acc: 98.63%, Val Loss: 0.0540, Val Acc: 94.74%
# Epoch: 11/20, Train Loss: 0.0099, Train Acc: 93.15%, Val Loss: 0.0508, Val Acc: 100.00%
# Epoch: 12/20, Train Loss: 0.0110, Train Acc: 93.15%, Val Loss: 0.1383, Val Acc: 94.74%
# Epoch: 13/20, Train Loss: 0.0062, Train Acc: 95.89%, Val Loss: 0.0486, Val Acc: 100.00%
# Epoch: 14/20, Train Loss: 0.0074, Train Acc: 95.89%, Val Loss: 0.1420, Val Acc: 94.74%
# Epoch: 15/20, Train Loss: 0.0028, Train Acc: 98.63%, Val Loss: 0.4180, Val Acc: 94.74%
# Epoch: 16/20, Train Loss: 0.0162, Train Acc: 93.15%, Val Loss: 0.2991, Val Acc: 89.47%
# Epoch: 17/20, Train Loss: 0.0036, Train Acc: 97.26%, Val Loss: 0.0155, Val Acc: 100.00%
# Epoch: 18/20, Train Loss: 0.0036, Train Acc: 97.26%, Val Loss: 0.2436, Val Acc: 94.74%
# Epoch: 19/20, Train Loss: 0.0024, Train Acc: 98.63%, Val Loss: 0.1310, Val Acc: 94.74%
# Epoch: 20/20, Train Loss: 0.0071, Train Acc: 95.89%, Val Loss: 0.0043, Val Acc: 100.00%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/multi-layers/Adam/model/gel_classifier-7.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/multi-layers/Adam/plots/loss_accuracy_plots/gel_classifier-7.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('vgg16', 'multi', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/multi-layers/Adam/model/gel_classifier-7.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 7)
# Out:
# [INFO] Accuracy: 77.27%
# [INFO] Precision: 84.38%
# [INFO] Recall: 77.27%
# [INFO] Confusion matrix:
#  [[ 6  5]
#  [ 0 11]]
# [INFO] AUC: 77.27%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 7)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #b2- Optimization Algorithm: SGD

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=8 --hardware_type='cpu' --pretrained_model='vgg16' --classifier_head='multi' --opt_alg='sgd' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/multi-layers/SGD/model/gel_classifier-8.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/multi-layers/SGD/plots/loss_accuracy_plots/gel_classifier-8.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of VGG16 model with the customized head:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.25, inplace=False)
#       (3): Linear(in_features=512, out_features=256, bias=True)
#       (4): ReLU()
#       (5): Dropout(p=0.5, inplace=False)
#       (6): Linear(in_features=256, out_features=2, bias=True)
#     )
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0376, Train Acc: 50.68%, Val Loss: 0.6877, Val Acc: 52.63%
# Epoch: 2/20, Train Loss: 0.0383, Train Acc: 46.58%, Val Loss: 0.6803, Val Acc: 52.63%
# Epoch: 3/20, Train Loss: 0.0375, Train Acc: 56.16%, Val Loss: 0.6659, Val Acc: 84.21%
# Epoch: 4/20, Train Loss: 0.0370, Train Acc: 56.16%, Val Loss: 0.6498, Val Acc: 94.74%
# Epoch: 5/20, Train Loss: 0.0370, Train Acc: 67.12%, Val Loss: 0.6336, Val Acc: 94.74%
# Epoch: 6/20, Train Loss: 0.0360, Train Acc: 76.71%, Val Loss: 0.6207, Val Acc: 94.74%
# Epoch: 7/20, Train Loss: 0.0353, Train Acc: 79.45%, Val Loss: 0.5993, Val Acc: 94.74%
# Epoch: 8/20, Train Loss: 0.0344, Train Acc: 78.08%, Val Loss: 0.5898, Val Acc: 94.74%
# Epoch: 9/20, Train Loss: 0.0357, Train Acc: 78.08%, Val Loss: 0.5658, Val Acc: 94.74%
# Epoch: 10/20, Train Loss: 0.0326, Train Acc: 91.78%, Val Loss: 0.5316, Val Acc: 100.00%
# Epoch: 11/20, Train Loss: 0.0315, Train Acc: 91.78%, Val Loss: 0.5216, Val Acc: 100.00%
# Epoch: 12/20, Train Loss: 0.0329, Train Acc: 89.04%, Val Loss: 0.4897, Val Acc: 100.00%
# Epoch: 13/20, Train Loss: 0.0321, Train Acc: 89.04%, Val Loss: 0.4715, Val Acc: 100.00%
# Epoch: 14/20, Train Loss: 0.0285, Train Acc: 94.52%, Val Loss: 0.4467, Val Acc: 100.00%
# Epoch: 15/20, Train Loss: 0.0286, Train Acc: 93.15%, Val Loss: 0.4285, Val Acc: 94.74%
# Epoch: 16/20, Train Loss: 0.0260, Train Acc: 90.41%, Val Loss: 0.3814, Val Acc: 100.00%
# Epoch: 17/20, Train Loss: 0.0250, Train Acc: 95.89%, Val Loss: 0.3458, Val Acc: 100.00%
# Epoch: 18/20, Train Loss: 0.0224, Train Acc: 93.15%, Val Loss: 0.3250, Val Acc: 100.00%
# Epoch: 19/20, Train Loss: 0.0243, Train Acc: 90.41%, Val Loss: 0.2909, Val Acc: 100.00%
# Epoch: 20/20, Train Loss: 0.0218, Train Acc: 91.78%, Val Loss: 0.2683, Val Acc: 100.00%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/multi-layers/SGD/model/gel_classifier-8.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/multi-layers/SGD/plots/loss_accuracy_plots/gel_classifier-8.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('vgg16', 'multi', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/VGG16/multi-layers/SGD/model/gel_classifier-8.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 8)
# Out:
# [INFO] Accuracy: 77.27%
# [INFO] Precision: 84.38%
# [INFO] Recall: 77.27%
# [INFO] Confusion matrix:
#  [[ 6  5]
#  [ 0 11]]
# [INFO] AUC: 77.27%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 8)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv
