# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Gel_Project_Image_Classification
# Out:
# /content/drive/MyDrive/Gel_Project_Image_Classification

# %% [markdown]
# #1- Training the Model with a Single Linear Layer as the Classifier Head

# %% [markdown]
# #a1- Optimization Algorithm: Adam

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=1 --hardware_type='cpu' --pretrained_model='resnet18' --classifier_head='single' --opt_alg='adam' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/single-layer/Adam/model/gel_classifier-1.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/single-layer/Adam/plots/loss_accuracy_plots/gel_classifier-1.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of ResNet18 model with the customized head:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0500, Train Acc: 38.36%, Val Loss: 0.7930, Val Acc: 42.11%
# Epoch: 2/20, Train Loss: 0.0324, Train Acc: 65.75%, Val Loss: 0.7548, Val Acc: 47.37%
# Epoch: 3/20, Train Loss: 0.0435, Train Acc: 64.38%, Val Loss: 0.7217, Val Acc: 47.37%
# Epoch: 4/20, Train Loss: 0.0268, Train Acc: 82.19%, Val Loss: 0.5638, Val Acc: 73.68%
# Epoch: 5/20, Train Loss: 0.0260, Train Acc: 79.45%, Val Loss: 0.6226, Val Acc: 73.68%
# Epoch: 6/20, Train Loss: 0.0225, Train Acc: 93.15%, Val Loss: 0.5318, Val Acc: 73.68%
# Epoch: 7/20, Train Loss: 0.0182, Train Acc: 91.78%, Val Loss: 0.6806, Val Acc: 57.89%
# Epoch: 8/20, Train Loss: 0.0180, Train Acc: 90.41%, Val Loss: 0.4870, Val Acc: 73.68%
# Epoch: 9/20, Train Loss: 0.0199, Train Acc: 89.04%, Val Loss: 0.4556, Val Acc: 68.42%
# Epoch: 10/20, Train Loss: 0.0167, Train Acc: 94.52%, Val Loss: 0.2518, Val Acc: 100.00%
# Epoch: 11/20, Train Loss: 0.0162, Train Acc: 94.52%, Val Loss: 0.2346, Val Acc: 94.74%
# Epoch: 12/20, Train Loss: 0.0136, Train Acc: 94.52%, Val Loss: 0.2161, Val Acc: 100.00%
# Epoch: 13/20, Train Loss: 0.0115, Train Acc: 95.89%, Val Loss: 0.2026, Val Acc: 100.00%
# Epoch: 14/20, Train Loss: 0.0104, Train Acc: 93.15%, Val Loss: 0.3514, Val Acc: 78.95%
# Epoch: 15/20, Train Loss: 0.0148, Train Acc: 95.89%, Val Loss: 0.2338, Val Acc: 89.47%
# Epoch: 16/20, Train Loss: 0.0072, Train Acc: 97.26%, Val Loss: 0.1639, Val Acc: 100.00%
# Epoch: 17/20, Train Loss: 0.0246, Train Acc: 94.52%, Val Loss: 0.1362, Val Acc: 100.00%
# Epoch: 18/20, Train Loss: 0.0124, Train Acc: 95.89%, Val Loss: 0.1617, Val Acc: 94.74%
# Epoch: 19/20, Train Loss: 0.0079, Train Acc: 98.63%, Val Loss: 0.1734, Val Acc: 94.74%
# Epoch: 20/20, Train Loss: 0.0095, Train Acc: 95.89%, Val Loss: 0.1228, Val Acc: 100.00%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/single-layer/Adam/model/gel_classifier-1.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/single-layer/Adam/plots/loss_accuracy_plots/gel_classifier-1.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# # Import the necessary libraries

# %%
import os
import time
import torch
import pandas as pd
import seaborn as sns
from PIL import Image
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, auc
import utils
import build_dataset
import prepare_model

# %% [markdown]
# #Loading and Preparing Test Dataset

# %%
# Load the test images
test_images = '/content/drive/MyDrive/Gel_Project_Image_Classification/test_images'

# Create a test dataset
test_dataset = build_dataset.GelElectrophoresisDataset(test_images, transform=utils.test_transform)

# Get the number of classes
num_classes = test_dataset.num_classes

# Create dataloader on test images
test_dataloader = DataLoader(test_dataset, batch_size=23, shuffle=False, num_workers=2)

# %% [markdown]
# #Loading The Model

# %%
def load_model(pretrained_model, classifier_head, num_classes, model_path):

    if pretrained_model == 'resnet18':
        model = prepare_model.resnet18(num_classes, classifier_head)
    elif pretrained_model == 'vgg16':
        model = prepare_model.vgg16(num_classes, classifier_head)
    elif pretrained_model == 'mobilenet-v3':
        model = prepare_model.mobilenet_v3(num_classes, classifier_head)
    else:
        raise ValueError("Invalid pretrained model")

    # Load the trained weights of the model from a saved checkpoint file
    model.load_state_dict(torch.load(model_path))

    print("[INFO] Loading the model...")

    # Choose the device to run inference on (GPU if available, else CPU)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    # Move the model to the device
    model = model.to(device)

    # Set the model to evaluation mode
    model.eval()

    print("[INFO] Model loaded!")

    # Return the loaded model and device
    return model, device

# %%
model, device=load_model('resnet18', 'single', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/single-layer/Adam/model/gel_classifier-1.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
def evaluate_metrics(model, device, test_dataloader, model_id):

    # Testing loop
    predictions = []
    targets = []

    # Disables gradient calculation (as gradients are not needed during evaluation)
    with torch.no_grad():
      for inputs, labels in test_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        predictions.extend(predicted.cpu().numpy())
        targets.extend(labels.cpu().numpy())

    # Calculate evaluation metrics
    accuracy = accuracy_score(targets, predictions)
    precision = precision_score(targets, predictions, average='weighted')
    recall = recall_score(targets, predictions, average='weighted')
    conf_mat = confusion_matrix(targets, predictions)
    fpr, tpr, thresholds = roc_curve(targets, predictions)
    roc_auc = auc(fpr, tpr)
    print('[INFO] Accuracy: {:.2f}%'.format(accuracy*100))
    print('[INFO] Precision: {:.2f}%'.format(precision*100))
    print('[INFO] Recall: {:.2f}%'.format(recall*100))
    print('[INFO] Confusion matrix:\n', conf_mat)
    print('[INFO] AUC: {:.2f}%'.format(roc_auc*100))

    # Plot confusion matrix
    plt.figure(figsize=(4, 3))
    sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues')
    plt.title('ConfusionMatrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    # Plot ROC curve
    plt.figure(figsize=(4, 3))
    plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = {:.2f}%)'.format(roc_auc*100))
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.show()

    # Store the evaluation metrics in a dictionary
    results = {
        'model_id': model_id,
        'accuracy': '{:.2f}%'.format(accuracy*100),
        'precision': '{:.2f}%'.format(precision*100),
        'recall': '{:.2f}%'.format(recall*100),
        'conf_mat': str(conf_mat.tolist()),
        'roc_auc': '{:.2f}%'.format(roc_auc*100)

    }

    return results

# %%
results = evaluate_metrics(model, device, test_dataloader, 1)
# Out:
# [INFO] Accuracy: 81.82%
# [INFO] Precision: 86.67%
# [INFO] Recall: 81.82%
# [INFO] Confusion matrix:
#  [[ 7  4]
#  [ 0 11]]
# [INFO] AUC: 81.82%

# %%
# Path to results CSV file
results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
def inference(model, device, test_dataloader, test_dataset, model_id):
    # Start inference timer
    inf_start = time.time()

    # Testing loop
    predictions = []
    correct = 0
    total = 0

    # Disables gradient calculation (as gradients are not needed during inference)
    with torch.no_grad():
        for inputs, labels in test_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            predictions.extend(predicted.cpu().numpy())

            # Display images with predicted and actual classes
            for j in range(len(labels)):
                # Get image name and path
                image_path = test_dataset.samples[j][0]
                image_name = os.path.basename(image_path)
                # Load and display image
                img = Image.open(image_path)
                plt.imshow(img, cmap='gray')
                plt.axis('off')
                plt.title(f'Predicted: {test_dataset.image_folder.classes[predictions[j]]}, Actual: {test_dataset.image_folder.classes[labels[j]]}')
                plt.show()

    # End inference timer
    inf_end = time.time()
    # Calculate inference time
    inf_time_secs = inf_end - inf_start
    # Convert seconds to minutes
    inf_time_mins = inf_time_secs / 60
    print("[INFO] Inference completed on test samples")
    # Print total inference time
    print(f"[INFO] Total inference time: {inf_time_secs:.2f} seconds, {inf_time_mins:.2f} minutes")

    # Store inference time in a dictionary
    results = {
      'model_id': model_id,
      'inference_time_secs': inf_time_secs
    }

    return results

# %%
results = inference(model, device, test_dataloader, test_dataset, 1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #b1- Optimization Algorithm: SGD

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=2 --hardware_type='cpu' --pretrained_model='resnet18' --classifier_head='single' --opt_alg='sgd' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/single-layer/SGD/model/gel_classifier-2.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/single-layer/SGD/plots/loss_accuracy_plots/gel_classifier-2.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of ResNet18 model with the customized head:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0378, Train Acc: 45.21%, Val Loss: 0.7822, Val Acc: 31.58%
# Epoch: 2/20, Train Loss: 0.0341, Train Acc: 64.38%, Val Loss: 0.5740, Val Acc: 73.68%
# Epoch: 3/20, Train Loss: 0.0263, Train Acc: 79.45%, Val Loss: 0.5401, Val Acc: 78.95%
# Epoch: 4/20, Train Loss: 0.0198, Train Acc: 87.67%, Val Loss: 0.6063, Val Acc: 68.42%
# Epoch: 5/20, Train Loss: 0.0290, Train Acc: 87.67%, Val Loss: 0.3436, Val Acc: 94.74%
# Epoch: 6/20, Train Loss: 0.0388, Train Acc: 83.56%, Val Loss: 0.4679, Val Acc: 78.95%
# Epoch: 7/20, Train Loss: 0.0182, Train Acc: 93.15%, Val Loss: 0.2856, Val Acc: 89.47%
# Epoch: 8/20, Train Loss: 0.0151, Train Acc: 93.15%, Val Loss: 0.3737, Val Acc: 94.74%
# Epoch: 9/20, Train Loss: 0.0073, Train Acc: 95.89%, Val Loss: 0.1994, Val Acc: 94.74%
# Epoch: 10/20, Train Loss: 0.0150, Train Acc: 95.89%, Val Loss: 0.1780, Val Acc: 94.74%
# Epoch: 11/20, Train Loss: 0.0121, Train Acc: 94.52%, Val Loss: 0.1614, Val Acc: 89.47%
# Epoch: 12/20, Train Loss: 0.0085, Train Acc: 95.89%, Val Loss: 0.2420, Val Acc: 94.74%
# Epoch: 13/20, Train Loss: 0.0055, Train Acc: 98.63%, Val Loss: 0.1561, Val Acc: 94.74%
# Epoch: 14/20, Train Loss: 0.0060, Train Acc: 95.89%, Val Loss: 0.2057, Val Acc: 84.21%
# Epoch: 15/20, Train Loss: 0.0037, Train Acc: 100.00%, Val Loss: 0.1177, Val Acc: 94.74%
# Epoch: 16/20, Train Loss: 0.0048, Train Acc: 97.26%, Val Loss: 0.1547, Val Acc: 100.00%
# Epoch: 17/20, Train Loss: 0.0092, Train Acc: 91.78%, Val Loss: 0.1643, Val Acc: 94.74%
# Epoch: 18/20, Train Loss: 0.0088, Train Acc: 94.52%, Val Loss: 0.0976, Val Acc: 100.00%
# Epoch: 19/20, Train Loss: 0.0038, Train Acc: 98.63%, Val Loss: 0.1017, Val Acc: 100.00%
# Epoch: 20/20, Train Loss: 0.0042, Train Acc: 98.63%, Val Loss: 0.0796, Val Acc: 100.00%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/single-layer/SGD/model/gel_classifier-2.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/single-layer/SGD/plots/loss_accuracy_plots/gel_classifier-2.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('resnet18', 'single', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/single-layer/SGD/model/gel_classifier-2.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 2)
# Out:
# [INFO] Accuracy: 68.18%
# [INFO] Precision: 80.56%
# [INFO] Recall: 68.18%
# [INFO] Confusion matrix:
#  [[ 4  7]
#  [ 0 11]]
# [INFO] AUC: 68.18%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 2)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #2- Training the Model with Multiple Linear Layers as the Classifier Head

# %% [markdown]
# #a2- Optimization Algorithm: Adam

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=3 --hardware_type='cpu' --pretrained_model='resnet18' --classifier_head='multi' --opt_alg='adam' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/multi-layers/Adam/model/gel_classifier-3.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/multi-layers/Adam/plots/loss_accuracy_plots/gel_classifier-3.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# [INFO] The full architecture of ResNet18 model with the customized head:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=256, out_features=2, bias=True)
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0390, Train Acc: 46.58%, Val Loss: 0.6325, Val Acc: 63.16%
# Epoch: 2/20, Train Loss: 0.0300, Train Acc: 72.60%, Val Loss: 0.7521, Val Acc: 36.84%
# Epoch: 3/20, Train Loss: 0.0303, Train Acc: 64.38%, Val Loss: 0.6129, Val Acc: 68.42%
# Epoch: 4/20, Train Loss: 0.0198, Train Acc: 95.89%, Val Loss: 0.3908, Val Acc: 94.74%
# Epoch: 5/20, Train Loss: 0.0161, Train Acc: 91.78%, Val Loss: 0.4220, Val Acc: 84.21%
# Epoch: 6/20, Train Loss: 0.0062, Train Acc: 94.52%, Val Loss: 0.2028, Val Acc: 94.74%
# Epoch: 7/20, Train Loss: 0.0090, Train Acc: 95.89%, Val Loss: 0.1740, Val Acc: 100.00%
# Epoch: 8/20, Train Loss: 0.0060, Train Acc: 95.89%, Val Loss: 0.3860, Val Acc: 84.21%
# Epoch: 9/20, Train Loss: 0.0119, Train Acc: 94.52%, Val Loss: 0.1815, Val Acc: 94.74%
# Epoch: 10/20, Train Loss: 0.0023, Train Acc: 98.63%, Val Loss: 0.3276, Val Acc: 89.47%
# Epoch: 11/20, Train Loss: 0.0028, Train Acc: 98.63%, Val Loss: 0.1100, Val Acc: 94.74%
# Epoch: 12/20, Train Loss: 0.0080, Train Acc: 93.15%, Val Loss: 0.0916, Val Acc: 94.74%
# Epoch: 13/20, Train Loss: 0.0311, Train Acc: 94.52%, Val Loss: 0.0357, Val Acc: 100.00%
# Epoch: 14/20, Train Loss: 0.0035, Train Acc: 97.26%, Val Loss: 1.7809, Val Acc: 42.11%
# Epoch: 15/20, Train Loss: 0.0467, Train Acc: 72.60%, Val Loss: 0.1747, Val Acc: 100.00%
# Epoch: 16/20, Train Loss: 0.0446, Train Acc: 93.15%, Val Loss: 0.2645, Val Acc: 89.47%
# Epoch: 17/20, Train Loss: 0.0126, Train Acc: 83.56%, Val Loss: 0.1122, Val Acc: 100.00%
# Epoch: 18/20, Train Loss: 0.0144, Train Acc: 91.78%, Val Loss: 0.1885, Val Acc: 94.74%
# Epoch: 19/20, Train Loss: 0.0107, Train Acc: 97.26%, Val Loss: 0.0757, Val Acc: 100.00%
# Epoch: 20/20, Train Loss: 0.0139, Train Acc: 94.52%, Val Loss: 0.1147, Val Acc: 94.74%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/multi-layers/Adam/model/gel_classifier-3.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/multi-layers/Adam/plots/loss_accuracy_plots/gel_classifier-3.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('resnet18', 'multi', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/multi-layers/Adam/model/gel_classifier-3.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 3)
# Out:
# [INFO] Accuracy: 81.82%
# [INFO] Precision: 86.67%
# [INFO] Recall: 81.82%
# [INFO] Confusion matrix:
#  [[ 7  4]
#  [ 0 11]]
# [INFO] AUC: 81.82%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 3)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #b2- Optimization Algorithm: SGD

# %%
# !python train.py --dataset_dir='/content/drive/MyDrive/Gel_Project_Image_Classification/dataset' --model_id=4 --hardware_type='cpu' --pretrained_model='resnet18' --classifier_head='multi' --opt_alg='sgd' --model_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/multi-layers/SGD/model/gel_classifier-4.pth' --plots_path='/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/multi-layers/SGD/plots/loss_accuracy_plots/gel_classifier-4.png' --results_file='/content/drive/MyDrive/Gel_Project_Image_Classification/results.csv'
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 239MB/s]
#
# [INFO] The full architecture of ResNet18 model with the customized head:
# ResNet(
#   (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=256, out_features=2, bias=True)
#   )
# )
#
# [INFO] Start training the model...
# Epoch: 1/20, Train Loss: 0.0373, Train Acc: 54.79%, Val Loss: 0.6979, Val Acc: 47.37%
# Epoch: 2/20, Train Loss: 0.0380, Train Acc: 54.79%, Val Loss: 0.6879, Val Acc: 57.89%
# Epoch: 3/20, Train Loss: 0.0374, Train Acc: 57.53%, Val Loss: 0.6850, Val Acc: 63.16%
# Epoch: 4/20, Train Loss: 0.0371, Train Acc: 65.75%, Val Loss: 0.6780, Val Acc: 68.42%
# Epoch: 5/20, Train Loss: 0.0349, Train Acc: 73.97%, Val Loss: 0.6890, Val Acc: 57.89%
# Epoch: 6/20, Train Loss: 0.0340, Train Acc: 78.08%, Val Loss: 0.6739, Val Acc: 78.95%
# Epoch: 7/20, Train Loss: 0.0332, Train Acc: 83.56%, Val Loss: 0.6641, Val Acc: 68.42%
# Epoch: 8/20, Train Loss: 0.0318, Train Acc: 76.71%, Val Loss: 0.6394, Val Acc: 73.68%
# Epoch: 9/20, Train Loss: 0.0344, Train Acc: 73.97%, Val Loss: 0.6230, Val Acc: 63.16%
# Epoch: 10/20, Train Loss: 0.0316, Train Acc: 79.45%, Val Loss: 0.6080, Val Acc: 73.68%
# Epoch: 11/20, Train Loss: 0.0318, Train Acc: 82.19%, Val Loss: 0.5812, Val Acc: 89.47%
# Epoch: 12/20, Train Loss: 0.0315, Train Acc: 86.30%, Val Loss: 0.5506, Val Acc: 84.21%
# Epoch: 13/20, Train Loss: 0.0296, Train Acc: 87.67%, Val Loss: 0.5205, Val Acc: 84.21%
# Epoch: 14/20, Train Loss: 0.0275, Train Acc: 91.78%, Val Loss: 0.5317, Val Acc: 84.21%
# Epoch: 15/20, Train Loss: 0.0257, Train Acc: 95.89%, Val Loss: 0.4833, Val Acc: 84.21%
# Epoch: 16/20, Train Loss: 0.0260, Train Acc: 93.15%, Val Loss: 0.4585, Val Acc: 89.47%
# Epoch: 17/20, Train Loss: 0.0223, Train Acc: 98.63%, Val Loss: 0.4592, Val Acc: 89.47%
# Epoch: 18/20, Train Loss: 0.0272, Train Acc: 87.67%, Val Loss: 0.4620, Val Acc: 84.21%
# Epoch: 19/20, Train Loss: 0.0200, Train Acc: 97.26%, Val Loss: 0.4385, Val Acc: 84.21%
# Epoch: 20/20, Train Loss: 0.0196, Train Acc: 94.52%, Val Loss: 0.3759, Val Acc: 89.47%
# [INFO] Finished training the model!
# [INFO] Model saved at /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/multi-layers/SGD/model/gel_classifier-4.pth
# [INFO] Training and validation loss/accuracy plots saved in /content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/multi-layers/SGD/plots/loss_accuracy_plots/gel_classifier-4.png
# [INFO] Training time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Loading The Model

# %%
model, device=load_model('resnet18', 'multi', num_classes, '/content/drive/MyDrive/Gel_Project_Image_Classification/CPU/ResNet18/multi-layers/SGD/model/gel_classifier-4.pth')
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [INFO] Loading the model...
# [INFO] Model loaded!

# %% [markdown]
# #Evaluate the model's performance on test images

# %%
results = evaluate_metrics(model, device, test_dataloader, 4)
# Out:
# [INFO] Accuracy: 90.91%
# [INFO] Precision: 92.31%
# [INFO] Recall: 90.91%
# [INFO] Confusion matrix:
#  [[ 9  2]
#  [ 0 11]]
# [INFO] AUC: 90.91%

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Define the columns to update
columns_to_update = ['accuracy', 'precision', 'recall', 'conf_mat', 'roc_auc']

# Iterate over the columns to update and assign the corresponding values from the 'results' dictionary
for column in columns_to_update:
    results_df.loc[filter, column] = results[column]

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Evaluation metrics results saved in {results_file}")
# Out:
# [INFO] Evaluation metrics results saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv

# %% [markdown]
# #Model Inference on Test Images

# %%
results = inference(model, device, test_dataloader, test_dataset, 4)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Read the existing results.csv file into a DataFrame
results_df = pd.read_csv(results_file)

# Filter the DataFrame based on the 'model_id' column to locate the specific row to update
filter = results_df['model_id'] == results['model_id']

# Update the 'inference_time_secs' column with the value from the 'results' dictionary
results_df.loc[filter, 'inference_time_secs'] = results['inference_time_secs']

# Save the updated results DataFrame back to the CSV file
results_df.to_csv(results_file, index=False)
print(f"[INFO] Inference time saved in {results_file}")
# Out:
# [INFO] Inference time saved in /content/drive/MyDrive/Gel_Project_Image_Classification/results.csv
